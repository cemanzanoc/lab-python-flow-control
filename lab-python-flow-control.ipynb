# %% [markdown]
# # Lab | Flow Control

# %% [markdown]
# ## Exercise: Managing Customer Orders Optimized
#
# In the last lab, you were starting an online store that sells various products. To ensure smooth operations, you developed a program that manages customer orders and inventory.
#
# You did so without using flow control. Let's go a step further and improve this code.
#
# Follow the steps below to complete the exercise:
#
# 1. Look at your code from the lab data structures, and improve repeated code with loops.
#
# 2. Instead of asking the user to input the name of three products that a customer wants to order, do the following:
#
#     a. Prompt the user to enter the name of a product that a customer wants to order.
#
#     b. Add the product name to the "customer_orders" set.
#
#     c. Ask the user if they want to add another product (yes/no).
#
#     d. Continue the loop until the user does not want to add another product.
#
# 3. Instead of updating the inventory by subtracting 1 from the quantity of each product, only do it for  the products that were ordered (those in "customer_orders").

# %%
#Step 1.Define a list called products with different fashion clothes
products=["t-shirt","mug","hat","book","keychain"]

#2.Create an empty dictionary called inventory
inventory={}

#3.Ask the user to input the quantity of each product available in the inventory.
# Use the product names from the list as key in the inventory and assign the respective quantity as values

for item in products:
    while True:
        try:
            quantity = int(input(f"Introduce the quantity of {item} available in the inventory: "))
            if quantity < 0:
                print(f"Error: The quantity of {item} cannot be negative. The value will be set to 0.")
                quantity = 0
            break
        except ValueError:
            print("Please enter a valid number.")
    inventory[item] = quantity
    print(f"There are {quantity} {item} available")


#4.Create an empty set
customer_orders=set()

#5.Ask the user to input the names of three products that the customer wants

answer= "yes"

while answer.lower() == "yes":
        order=input(f"Introduce your order, remember that it should be only these items {products}").lower()
        
        if order not in products:
            print(f"{order} is not a valid product.")

        elif inventory[order]<=0:
            print(f"You can not order {order},there is not enough stock")
        
        else:
            print(f"You ordered {order}")
            customer_orders.add(order)
            
        
        #Question if you want to add more items
        answer=input("Do you want to include another item? Answer Yes/No:").lower()
            
        while answer not in ["yes", "no"]:
            answer = input("Valid answer only 'yes' or 'no'. Do you want to include another item? Answer Yes/No: ").lower()
    

#6.Print your customer_order set
print("\nYour order is:", customer_orders)

#7.Calculate statistics
#7.1 Total products ordered
total_products_ordered=len(customer_orders)
total_available_products=len(products)
print(f"\nTotal products ordered: {total_products_ordered}")

#7.2 Percentage of products ordered
percentage_ordered=(total_products_ordered/total_available_products)*100
print(f"Percentage ordered compared to the total available products {percentage_ordered}%")

#Store statistics in a tuple
order_status=(total_products_ordered,percentage_ordered)

#8.Print the order statistics in a concrete format
print(f"\nOrder Statistics:\nTotal Products Ordered: {total_products_ordered}\nPercentage of Products Ordered: {percentage_ordered}%\n")

#9.Update the inventory
for item in customer_orders:
    if inventory[item]>0:
        inventory[item]-=1
    else:
            print(f"Cannot reduce {item}, no stock available!")


#10.Print the Updated inventory
for item,quantity in inventory.items():
    print(f"There are {quantity} {item} left")

    if quantity==0 :
        print(f"Alert! There are not {item} left in the inventory")
# Out:
# There are 0 t-shirt available
# There are 2 mug available
# There are 4 hat available
# There are 6 book available
# There are 3 keychain available
# You can not order t-shirt,there is not enough stock
# You ordered mug
# You ordered hat
#
# Your order is: {'hat', 'mug'}
#
# Total products ordered: 2
# Percentage ordered compared to the total available products 40.0%
#
# Order Statistics:
# Total Products Ordered: 2
# Percentage of Products Ordered: 40.0%
#
# There are 0 t-shirt left
# Alert! There are not t-shirt left in the inventory
# There are 1 mug left
# There are 3 hat left
# There are 6 book left
# There are 3 keychain left
